# %%
#contoh fungsi
def helloPython():
    print(f'welcome in python languaga')


#contoh fungsi parameter
    def fullName(firstname = "Dorce", lastname = 'Ambrauw'):
    print(f'hello name saya {firstname} marga saya {lastname}')

    def maxValue(val_1, val_2, val_3):
    print(f'2, 3, 4, 6, 8')

    def countCircleArea(diameter, phi = '3.14'):
    print(f'sebuah lingkaran berdiameter {8} {phi}')

    def info(suhu, daerah='bogor', satuan = 'Celcius'):
    print(f"suhu skarang di {daerah} : {suhu} {satuan}")



#contoh fungsi return
    #soal fungsi untuk menjumblakan total nilai dari list
    #Soal 1
def Jumblakan_total(nilai_list):
    total = sum(nilai_list)
    return total
    nilai_list = [1, 2, 3, 4, 5]
    print(Jumblakan_total(nilai_list))

    #soal fungsi untuk mencari nilai terbesar dari sekumpulan list
    #soal 2
def cari_nilai_terbesar(dalam_list):
    if not dalam_list:
       return None
    nilai_terbesar = max(dalam_list)
    return nilai_terbesar
angka_list =[10, 24, 3, 56, 72, 1, 5]
print("Nilai terbesar dalam list adalah:", cari_nilai_terbesar(angka_list))

    #soal fungsi untuk menjumblakan 2 buah list
    #Soal 3
def Jumblakan_list(list1, list2):
    if len(list1) != len(list2):
        raise ValueError("kedua list harus memiliki panJang yang sama.")
        hasil =[]
        for i in range(len(list1)):
            Jumblah = list1[i] + list2[i]
          
            return hasil
           
            hasil.append(Jumblah)
            list_a =[1, 2, 3]
            list_b =[4, 5, 6]
            list_hasil = Jumblah_list(list_a, list_b)
            print(list_hasil)
